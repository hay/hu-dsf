# %%
import pandas as pd

# %%
df = pd.read_json("movies.json")

# %%
# List all movies from a given year
year = 1983
df[df["year"] == year]
# Out:
#                                                 actors          director  \
# 86   [Francesco Maselli, Fred Williams, Pina Bausch...  Federico Fellini
# 185  [Roberto Benigni, Nicoletta Braschi, Serena Gr...   Roberto Benigni
# 186  [Al Pacino, Michelle Pfeiffer, F. Murray Abrah...    Brian De Palma
# 443  [Kim Basinger, Julie Andrews, Burt Reynolds, S...     Blake Edwards
# 474  [Willeke van Ammelrooy, Josine van Dalsum, Huu...         Dick Maas
#
#      duration                                             genres  \
# 86        128  [drama film, comedy film, war film, musical film]
# 185        96                                      [comedy film]
# 186       170              [drama film, action film, crime film]
# 443       110                    [comedy-drama, romantic comedy]
# 474        94                [horror film, science fiction film]
#
#                        title  year
# 86     And the Ship Sails On  1983
# 185              Tu mi turbi  1983
# ...

# %%
# Longer than 200 minutes
minutes = 200
df[df["duration"] > minutes]
# Out:
#                                                 actors              director  \
# 5    [Jürgen Prochnow, Otto Sander, Sky du Mont, Kl...     Wolfgang Petersen
# 80   [Peter Berling, Mihály Ráday, Mihály Víg, Jáno...             Béla Tarr
# 90   [Thomas Mitchell, George Reeves, Carroll Nye, ...          George Cukor
# 160  [Peter Jackson, John Rhys-Davies, Hugo Weaving...         Peter Jackson
# 174  [Cesare Danova, Douglas Wilmer, Andrew Keir, H...  Joseph L. Mankiewicz
# 444  [Bob Dylan, Allen Ginsberg, Joan Baez, D. A. P...       Martin Scorsese
#
#      duration                                             genres  \
# 5         293  [war film, historical film, film based on lite...
# 80        450   [drama film, art film, film based on literature]
# 90        238  [historical film, film based on literature, dr...
# 160       201  [drama film, fantasy film, action film, film b...
# 174       241  [war film, biographical film, romance film, pe...
# ...

# %%
z
# Out:
#                                                 actors              director  \
# 12   [Carlos Álvarez-Nóvoa, Norma Aleandro, Natalia...    Juan J. Campanella
# 13   [Kevin Costner, Evan Rachel Wood, Joan Allen, ...           Mike Binder
# 14   [Jean Rochefort, Nathalie Baye, Kristin Scott ...       Guillaume Canet
# 16   [Barbra Streisand, Blythe Danner, Jeroen Krabb...      Barbra Streisand
# 18   [Bryan Cranston, Jimmy Carter, Alan Arkin, Joh...           Ben Affleck
# 28   [Cecilia Roth, Carmen Maura, Agustín Almodóvar...       Pedro Almodóvar
# 33   [Stephen King, Pat Hingle, Emilio Estevez, Yea...          Stephen King
# 34   [Alexander Sokurov, Mikhail Piotrovsky, Sergey...     Alexander Sokurov
# 37   [Geoffrey Arend, Natalie Portman, Michael West...            Zach Braff
# 40   [Erick Avari, Harve Presnell, Roark Critchlow,...          Steven Brill
# 48   [Guillaume Canet, Michel Serrault, Bernard Le ...      Christian Carion
# ...
