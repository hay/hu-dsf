# %%
import pandas as pd

# %%
df = pd.read_csv("temperatures.csv")
df.head()
# Out:
#         day  temperature
# 0  20170101          0.5
# 1  20170102          3.0
# 2  20170103          5.0
# 3  20170104          5.8
# 4  20170105          0.0

# %%
df["temperature"].plot()

# %%
df.plot(y = "temperature")

# %%
df.plot(kind = "hist", y = "temperature", bins = 10)

# %%
df.plot(y = "temperature", kind = "bar")

# %%
df2 = df[0:5]
df2
# Out:
#         day  temperature
# 0  20170101          0.5
# 1  20170102          3.0
# 2  20170103          5.0
# 3  20170104          5.8
# 4  20170105          0.0

# %%
df[0:10].plot(y = "temperature", kind = "bar")

# %%
df[0:10].plot(y = "temperature", kind = "barh")

# %%
df[0:10].plot(y = "temperature", kind = "bar", title = "Dutch temperatures during the first ten days of 2017")
