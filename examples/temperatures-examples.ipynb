# %%
import pandas as pd

# %%
df = pd.read_csv("temperatures.csv")

# %%
df.head()
# Out:
#         day  temperature
# 0  20170101          0.5
# 1  20170102          3.0
# 2  20170103          5.0
# 3  20170104          5.8
# 4  20170105          0.0

# %%
df.tail()
# Out:
#           day  temperature
# 360  20171227          5.1
# 361  20171228          3.9
# 362  20171229          2.8
# 363  20171230          8.8
# 364  20171231         10.6

# %%
df.index
# Out:
# RangeIndex(start=0, stop=365, step=1)

# %%
df["temperature"].plot()

# %%
df["temperature"].describe()
# Out:
# count    365.000000
# mean      10.965753
# std        6.034407
# min       -3.800000
# 25%        6.600000
# 50%       10.900000
# 75%       16.100000
# max       23.600000
# Name: temperature, dtype: float64

# %%
df["day"].head()
# Out:
# 0    20170101
# 1    20170102
# 2    20170103
# 3    20170104
# 4    20170105
# Name: day, dtype: int64

# %%
df_cool = df[df["temperature"] < 0]

# %%
df_cool.head()
# Out:
#          day  temperature
# 5   20170106         -3.0
# 6   20170107         -0.2
# 15  20170116         -1.6
# 16  20170117         -3.4
# 17  20170118         -3.8

# %%
df_cool.to_csv("cool.csv")

# %%
df["temperature"].value_counts().head()
# Out:
# 18.6    7
# 5.9     6
# 15.8    5
# 14.1    4
# 11.7    4
# Name: temperature, dtype: int64

# %%
snacks = pd.Series(["Znack", "Mars", "Twix", "mars", "Mars", "Oreo"])

# %%
snacks
# Out:
# 0    Znack
# 1     Mars
# 2     Twix
# 3     mars
# 4     Mars
# 5     Oreo
# dtype: object

# %%
snacks.value_counts()
# Out:
# Mars     2
# Oreo     1
# mars     1
# Twix     1
# Znack    1
# dtype: int64
